# %%
import os

os.path.getsize('v3_MRT3_every_day__forecasts.json') // (1024**2)
# Out:
# 726

# %%
import pandas as pd

pd.read_json('v3_MRT3_every_day__forecasts.json')
# Out:
#          prewarm_steps  sample  steps            feature  \
# 0                    0       0      0           EMA_mood
# 1                    0       0      0   EMA_disappointed
# 2                    0       0      0         EMA_scared
# 3                    0       0      0          EMA_worry
# 4                    0       0      0           EMA_down
# ...                ...     ...    ...                ...
# 2771845              0       0     10  EMA_concentration
# 2771846              0       0     10     EMA_resilience
# 2771847              0       0     10          EMA_tired
# 2771848              0       0     10      EMA_satisfied
# 2771849              0       0     10        EMA_relaxed
#
#                                               model_id  run  participant  \
# 0        data_12600_201.csv_participant_201_date_100.0    1          201
# 1        data_12600_201.csv_participant_201_date_100.0    1          201
# ...
