# %%
from training_utils import get_project_dict

d = get_project_dict('test_project')
# Out:
# d:\ZI Mannheim\KI Reallabor\ema_forecast_control\ema_forecast_control\utils\training_utils.py:10: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml

# %%
d['hyperparameters']
# Out:
# {'learning_rate': [0.001, 0.0005], 'batch_size': [16, 32]}

# %%
d['combined_hyperparameters']
# Out:
# [{'seq_len': 16, 'n_epochs': 10}, {'seq_len': 32, 'n_epochs': 20}]

# %%
import multitasking_utils as mu

configs, n_workers = mu.prepare_configuration_batch(d)
len(configs)
# Out:
# Not using GPUs for training.
# 4

# %%
dict1 = {'a':1, 'b':2}
dict2 = {'b':3, 'c':4}

combined_dict = {**dict2, **dict1}
combined_dict
# Out:
# {'b': 2, 'c': 4, 'a': 1}
