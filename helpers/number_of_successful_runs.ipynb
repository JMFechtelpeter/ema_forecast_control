# %%
import os
import glob
import sys
sys.path.append('..')
import utils

main_dir = '/home/janik.fechtelpeter/Documents/ordinal-bptt/results/dim_zy_MRT1_EveryValidDay_Smoothed'

all_hyper_paths = set([os.path.split(p)[0] for p in glob.glob(f'{main_dir}/**/*.pkl', recursive=True)])
all_model_paths = set([os.path.split(p)[0] for p in glob.glob(f'{main_dir}/**/*.pt', recursive=True)])

failures = sorted(all_hyper_paths.difference(all_model_paths))

print(f'{len(failures)}/{len(all_hyper_paths)} runs failed')
# Out:
# 0/47200 runs failed
