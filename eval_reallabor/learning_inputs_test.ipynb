# %%
import attrs
import torch as tc

class System():

    def __init__()

    def step(self, z, s):
        return self.A * z + self.W1 @ tc.relu(self.W2 @ z + self.h2) + self.C @ s

    def generate(self, T, z0, inputs):
        result = tc.zeros()
        for t in range(T):
            pass
