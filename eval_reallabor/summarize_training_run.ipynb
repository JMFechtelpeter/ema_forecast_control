# %%
import sys
sys.path.append('..')
from eval_reallabor_utils import summarize_training_run

main_dir = '/home/janik.fechtelpeter/Documents/ordinal-bptt/results/v2_dim_zyproj_MRT1_EveryValidDay_Smoothed'
summarize_training_run(main_dir, summary_file='../results/v2_dim_zyproj_MRT1_EveryValidDay_Smoothed/training_summary.yml',
                       ignore_hypers=['pbar_descr'])
# Out:
# Successfully added v2_dim_zyproj_MRT1_EveryValidDay_Smoothed to training run summary
