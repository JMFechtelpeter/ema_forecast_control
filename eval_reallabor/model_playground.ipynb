# %%
import eval_reallabor_utils
import torch as tc
import matplotlib.pyplot as plt
import custom_rcparams as crc

model_dir = '/home/janik.fechtelpeter/Documents/bptt/results/MRT1_Gridsearch02_Smoothed/dim_z_20_dim_y_05_dim_x_proj_00_data_11228_34.csv_participant_34_date_165/007'

model, test_dataset = eval_reallabor_utils.load_model_and_data(model_dir)
dim_x = model.args['dim_x']
dim_s = model.args['dim_s']

# %%
data = tc.ones((100, dim_x), dtype=tc.float32)*4
inputs = tc.ones((100, dim_s), dtype=tc.float32)
model.plot_prediction(data, inputs, alpha=0);
